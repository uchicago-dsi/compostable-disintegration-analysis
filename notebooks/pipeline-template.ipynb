# %%
import pandas as pd
from abc import ABC, abstractmethod

# %%
DATA_FOLDER = "../data/"

# %% [markdown]
# ### Set Up Items

# %%
ITEMS_PATH = DATA_FOLDER + "CFTP Test Item Inventory with Dimensions - All Trials.xlsx"
items = pd.read_excel(ITEMS_PATH, sheet_name=0, skiprows=3)
items.head(2)
# Out:
#   Item ID  Item Format    Brand Manufacturer Item SKU  \
# 0      A1         Bowl  BÉSICS®       WeiMon  WM-W270
# 1      A2  Hot Cup Lid  BÉSICS®     Multiple      NaN
#
#                    Item Name        Item Description Refined  \
# 0  PLA-lined Paper Bowl 12oz         BÉSICS® 12 oz Soup bowl
# 1           CPLA Hot Cup Lid  BÉSICS® 12oz CPLA Hot Cup Lid
#
#   Item Description From Trial Item ID.1 Material Class I  ...  \
# 0                 BESICS Bowl       NaN            Fiber  ...
# 1                 Hot cup lid       NaN       Biopolymer  ...
#
#                Material Composition Certification @ time of testing      Kit   \
# 0  Paper, PLA lining, adhesive, ink                             BPI  Baseline
# 1                  Crystallized PLA                             BPI  Baseline
#
#   Initial Weight 1 Initial Weight 2 Initial Weight 3  \
# 0             8.12             8.10             8.12
# 1             3.58             3.58             3.56
#
#    Average Initial Weight, g  Item Dimensions Compiled  Item Capacity, mL  \
# 0                   8.113333     3’’ diameter, 2.5’’ H                NaN
# 1                   3.573333   3.5’’ diameter, 0.5’’ H                NaN
#
#    Notes
# 0    NaN
# 1    NaN
#
# [2 rows x 23 columns]

# %%
items['Start Weight'] = items['Average Initial Weight, g']

# %%
items_cols = [
    'Item ID',
    'Item Name',
    'Item Description Refined',
    'Material Class I',
    'Material Class II',
    'Material Class III',
    'Start Weight'
    ]

# %%
items_clean = items[items_cols]
items_clean.head(2)
# Out:
#   Item ID                  Item Name        Item Description Refined  \
# 0      A1  PLA-lined Paper Bowl 12oz         BÉSICS® 12 oz Soup bowl
# 1      A2           CPLA Hot Cup Lid  BÉSICS® 12oz CPLA Hot Cup Lid
#
#   Material Class I            Material Class II Material Class III  \
# 0            Fiber                  Lined Fiber    PLA lined Paper
# 1       Biopolymer  Rigid Biopolymer (< 0.75mm)               CPLA
#
#    Start Weight
# 0      8.113333
# 1      3.573333

# %%
item2id = {key.strip(): value for key, value in items_clean.set_index('Item Description Refined')['Item ID'].to_dict().items()}
item2id
# Out:
# {'BÉSICS® 12 oz Soup bowl': 'A1',
#  'BÉSICS® 12oz CPLA Hot Cup Lid': 'A3',
#  'BÉSICS® 250mL PLA-lined Bagasse Leaf Bowl': 'A4',
#  'BÉSICS® 8oz CPLA Hot cup lid': 'A16',
#  'BÉSICS® Box with Lid AND Fry Tray': 'A6',
#  'BÉSICS® Lined Paper Box with Lid': 'A7',
#  'BÉSICS® Spoon 6"': 'A9',
#  'BÉSICS® Uncoated paper fry tray': 'Q',
#  'Fabrikal 16 oz PLA cold cup': 'A11',
#  'Kraft Control 10"x5" 1-ply': 'A12',
#  'Bagasse Clamshell 9x9': 'O',
#  'BÉSICS® 12oz Hot Cup': 'A14',
#  'BÉSICS® 6" Spoon': 'A15',
#  'Bin Liner Bag 2.5 gal': 'A17',
#  'Cellulose bag CONTROL': 'A18',
#  'Coffee Pod': 'A19',
#  'Kraft butcher paper CONTROL': 'A20',
#  'Moulded fiber bowl 16oz': 'A21',
#  'Navel orange peel': 'A22',
#  'PLA Cold Cup 12oz': 'A23',
#  'PLA Cold Cup Lid 8oz': 'V',
#  'Spoon PLA 6"': 'A25',
#  'Straw PHA 8"': 'A26',
#  '16oz NoTree Paper Hot Cup - World Centric': 'P',
#  '3Gallon Food Scrap Bag - World Centric': 'K3',
#  '8" Kraft straw ST-PA-8-K': 'B',
#  'Alter Eco Quinoa SUP 2018': 'A30',
#  'BÉSICS® Leaf Plate': 'A31',
#  'Elk Packaging SUP with white outer 2018': 'A32',
#  'Fiber Clamshell, Lined 9x9x3 SKU TO-SC-U9L-LF': 'A33',
#  'Fiber Cutlery, Spoon - World Centric': 'C',
#  'Large natural clear colour bag': 'A35',
#  'PLA Cold Cup 14oz': 'A36',
#  'Printed small bag with brown background and logo': 'A37',
#  'Small zippered clear colour bag': 'A38',
#  'SUP no Zip - large brown': 'A39',
#  'TPLA Spoon - World Centric': 'K1',
#  'Vegware Blue Paper Straw': 'A41',
#  'Vegware Fork': 'A42',
#  'Vegware PLA Straw': 'A43',
#  'Vegware Spoon': 'I',
#  'WR3 - Agave Spoon': 'A45',
#  'WR3 - Agave Straw': 'K2',
#  'WR3 - Bagasse Clamshell': 'J',
#  'WR3 - Coffee Bag 1': 'A48',
#  'WR3 - Coffee Bag 2': 'S',
#  'WR3 - Coffee Bag 3': 'A50',
#  'WR3 - Coffee Bag 4': 'A51',
#  'WR3 - CPLA Spoon': 'A52',
#  'WR3 - Hot Cup green': 'A53',
#  'WR3 - Hot Cup natural': 'D',
#  'WR3 - Paper Spoon': 'A55',
#  'WR3 - PLA portion cup 16oz': 'H',
#  'WR3 - Soup bowl': 'A57',
#  'WR3 - Soup Bowl 32oz': 'A58',
#  'WR3 - Stand up Biopolymer Pouch': 'A59',
#  'WR3 - Unlined Bella Bowl': 'A60',
#  'Wrapper for TPLA Spoon SP-PS-I': 'A61',
#  'BÉSICS® 8 oz Soup Bowl': 'A62',
#  'BÉSICS® Cellulose bag 5x7in': 'A63',
#  'BÉSICS® Fibreware Bowl 16oz': 'A64',
#  'BÉSICS® Fibreware Clamshell 850mL': 'A65',
#  'BÉSICS® Fibreware Clamshell 9x9': 'A66',
#  'BÉSICS® Sleeve': 'A67',
#  'BÉSICS® Wrap': 'A68',
#  'CPLA Fork 6" - Stalk Market': 'A69',
#  'CPLA Knife 6" - Stalk Market': 'A70',
#  'D&W 32oz Square PLA Box': 'A71',
#  'D&W PLA Lid 32oz': 'A72',
#  'Ecotainer PLA-Lined Soup Bowl 12oz': 'A73',
#  'Fabrikal PLA Cold Cup 20oz': 'A74',
#  'Kraft Control 10"x5" 2-ply': 'A75',
#  'MPLA Spoon - NaturTec': 'A76',
#  'PLA Foam Tray': 'A77',
#  'SPP Unlined Paper Tray (hot dog tray)': 'A78',
#  'SUP with Zip - kraft outer (3 mil)': 'A79',
#  'SUP with Zip - metallized (2 mil)': 'A80',
#  'PLA Lid: 32oz Burrito Bowl SKU BOL-CS-UBB': 'A81'}

# %% [markdown]
# ### Define Pipeline Class

# %%
class AbstractDataPipeline(ABC):
    @abstractmethod
    def load_data(self):
        pass

    @abstractmethod
    def process_data(self, data):
        pass

    @abstractmethod
    def save_data(self, data):
        pass

    def run(self):
        data = self.load_data()
        processed_data = self.process_data(data)
        self.save_data(processed_data)

# %%
import pandas as pd

class ClosedLoopPipeline(AbstractDataPipeline):
    def load_data(self, excel_path, sheet_name, skiprows):
        """Loads data from a specific sheet in an Excel file."""
        return pd.read_excel(excel_path, sheet_name=sheet_name, skiprows=skiprows)

    def process_data(self, weight_df, area_df, items_clean):
        """Processes the weight and area DataFrames, then merges with items_clean."""
        # Filter for "Second Removal"
        weight = weight_df[weight_df['Trial Stage'] == "Second Removal"]
        area = area_df[area_df['Trial Stage'] == "Second Removal"]
        
        # Melt the DataFrames
        weight_melted = self.melt_data_frame(weight, '% Residuals (Weight)')
        area_melted = self.melt_data_frame(area, '% Residuals (Area)')

        # Merge melted DataFrames
        observations_closed_loop = pd.merge(weight_melted, area_melted, 
                                            on=['Facility Name', 'Trial Stage', 'Bag Set', 'Bag Number', 'Item ID'], 
                                            how='outer')
        
        # Rename and select relevant columns
        observations_closed_loop.rename(columns={'Facility Name': 'Trial'}, inplace=True)
        observations_closed_loop = observations_closed_loop[['Trial', 'Item ID', '% Residuals (Weight)', '% Residuals (Area)']]
        
        # Join with items_clean and select columns
        joined_cl = pd.merge(items_clean, observations_closed_loop, on="Item ID")
        keep_cols = ["Trial", "Item ID", "Item Name", "Item Description Refined",
                     "Material Class I", "Material Class II", "Material Class III",
                     "Start Weight", "% Residuals (Weight)", "% Residuals (Area)"]
        return joined_cl[keep_cols]

    def melt_data_frame(self, df, value_name):
        """Helper method to melt DataFrames."""
        return df.melt(id_vars=['Facility Name', 'Trial Stage', 'Bag Set', 'Bag Number'],
                       value_vars=['N', 'O', 'Q', 'V', 'B', 'D', 'H', 'I', 'J', 'K', 'K1', 'K2', 'K3', 'N', 'O', 'P', 'Q', 'S', 'V'],
                       var_name='Item ID',
                       value_name=value_name).dropna(subset=[value_name]).reset_index(drop=True)

    def save_data(self, df, output_path):
        """Saves the DataFrame to a CSV file."""
        df.to_csv(output_path, index=False)

# %%
closed_loop_pipeline = ClosedLoopPipeline()
TEN_TRIALS_PATH = DATA_FOLDER + "Donated Data 2023 - Compiled Field Results for DSI.xlsx"
items_clean = pd.DataFrame()  # Assuming this is prepared elsewhere

observations_weight = closed_loop_pipeline.load_data(TEN_TRIALS_PATH, sheet_name=3, skiprows=2)
observations_sa = closed_loop_pipeline.load_data(TEN_TRIALS_PATH, sheet_name=4, skiprows=2)
processed_data = closed_loop_pipeline.process_data(observations_weight, observations_sa, items_clean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1379/1591286208.py in ?()
#       3 items_clean = pd.DataFrame()  # Assuming this is prepared elsewhere
#       4
#       5 observations_weight = closed_loop_pipeline.load_data(TEN_TRIALS_PATH, sheet_name=3, skiprows=2)
#       6 observations_sa = closed_loop_pipeline.load_data(TEN_TRIALS_PATH, sheet_name=4, skiprows=2)
# ----> 7 processed_data = closed_loop_pipeline.process_data(observations_weight, observations_sa, items_clean)
#
# /tmp/ipykernel_1379/3344574401.py in ?(self, weight_df, area_df, items_clean)
#      24         observations_closed_loop.rename(columns={'Facility Name': 'Trial'}, inplace=True)
#      25         observations_closed_loop = observations_closed_loop[['Trial', 'Item ID', '% Residuals (Weight)', '% Residuals (Area)']]
#      26
#      27         # Join with items_clean and select columns
# ---> 28         joined_cl = pd.merge(items_clean, observations_closed_loop, on="Item ID")
#      29         keep_cols = ["Trial", "Item ID", "Item Name", "Item Description Refined",
#      30                      "Material Class I", "Material Class II", "Material Class III",
#      31                      "Start Weight", "% Residuals (Weight)", "% Residuals (Area)"]
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'Item ID'

# %%
observations_weight.head()
# Out:
#            Facility Name  Trial ID    Trial Stage   Bag Set Bag Number   N  \
# 0  Facility 1 ( Windrow)  WR004-01  First Removal  A (blue)         10 NaN
# 1  Facility 1 ( Windrow)  WR004-01  First Removal  A (blue)          6 NaN
# 2  Facility 1 ( Windrow)  WR004-01  First Removal  A (blue)          7 NaN
# 3  Facility 1 ( Windrow)  WR004-01  First Removal  A (blue)          8 NaN
# 4  Facility 1 ( Windrow)  WR004-01  First Removal  A (blue)          9 NaN
#
#     O   Q   V      B  ...   K     K1     K2     K3  N.1  O.1   P  Q.1   S  V.1
# 0 NaN NaN NaN  0.059  ... NaN  0.986    NaN  0.546  NaN  NaN NaN  NaN NaN  NaN
# 1 NaN NaN NaN  0.022  ... NaN  0.696  0.007  0.572  NaN  NaN NaN  NaN NaN  NaN
# 2 NaN NaN NaN  0.018  ... NaN  0.933  0.023  0.313  NaN  NaN NaN  NaN NaN  NaN
# 3 NaN NaN NaN  0.220  ... NaN  0.909  0.000  0.412  NaN  NaN NaN  NaN NaN  NaN
# 4 NaN NaN NaN  0.028  ... NaN  0.928  0.050  0.650  NaN  NaN NaN  NaN NaN  NaN
#
# [5 rows x 24 columns]

# %%
# Save data
closed_loop_pipeline.save_data(processed_data, "processed_data.csv")
